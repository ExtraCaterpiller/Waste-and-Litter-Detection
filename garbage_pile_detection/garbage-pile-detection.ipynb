# %% [markdown]
# # Download Dataset

# %%
# !pip3 install gdown

# %%
import gdown
gdown.download(id='######', output='./', quiet=False)

# %%
# !unzip /kaggle/working/garbage__pile.zip -d /kaggle/working/

# %% [markdown]
# # Import Yolo

# %%
# !pip install -U ultralytics

# %%
from ultralytics import YOLO

# %% [markdown]
# # Dataset Preparation

# %%
# !rm -rf /kaggle/working/garbage__pile/README.dataset.txt
# !rm -rf /kaggle/working/garbage__pile/README.roboflow.txt
# !rm -rf /kaggle/working/garbage__pile.zip

# %%
import shutil

# %%
shutil.copy('/kaggle/input/config-garbage-pile/data.yaml', '/kaggle/working/')
# Out:
# '/kaggle/working/data.yaml'

# %% [markdown]
# # Model

# %%
model = YOLO('yolov8n.yaml')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
results = model.train(data='./data.yaml', epochs=250, patience=40)

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.0.231 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /kaggle/working/garbage__pile/labels/val.cache... 306 images, 18 backgrounds, 0 corrupt: 100%|██████████| 306/306 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 20/20 [00:04<00:00,  4.26it/s]
#                    all        306        323      0.841      0.715      0.756      0.413
# Speed: 0.9ms preprocess, 3.2ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs/detect/train2

# %% [markdown]
# # Download runs and wandb folder

# %%
# !zip -r runs.zip /kaggle/working/runs

# %%
from IPython.display import FileLink
FileLink(r'./runs.zip')
# Out:
# /kaggle/working/runs.zip

# %%
# !zip -r wandb.zip /kaggle/working/wandb

# %%
from IPython.display import FileLink
FileLink(r'wandb.zip')
# Out:
# /kaggle/working/wandb.zip
