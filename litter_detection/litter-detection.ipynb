# %% [markdown]
# # Install and Import Libraries

# %%
# !pip install -U ipywidgets
# !pip install -U ultralytics
# !pip3 install gdown

# %%
import ultralytics
import gdown

# %% [markdown]
# # Dataset Download

# %%
gdown.download(id='######', output='./')

# %% [markdown]
# # Data Preparation

# %%
# !unzip /kaggle/working/Litter_dataset.zip -d /kaggle/working/

# %%
# !rm -rf /kaggle/working/Litter_dataset.zip

# %% [markdown]
# # Model

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.yaml')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
results = model.train(data='./Litter_dataset/data.yaml', epochs=300, patience=50)

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.0.231 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /kaggle/working/Litter_dataset/labels/val.cache... 247 images, 5 backgrounds, 0 corrupt: 100%|██████████| 247/247 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 349, len(boxes) = 406. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 16/16 [00:03<00:00,  4.10it/s]
#                    all        247        406      0.407      0.323       0.27      0.108
# Speed: 1.2ms preprocess, 3.1ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to runs/detect/train2

# %%
# !zip -r runs.zip /kaggle/working/runs

# %%
from IPython.display import FileLink
FileLink(r'runs.zip')
# Out:
# /kaggle/working/runs.zip

# %%
# !zip -r wandb.zip /kaggle/working/wandb

# %%
from IPython.display import FileLink
FileLink(r'wandb.zip')
# Out:
# /kaggle/working/wandb.zip
