# %% [markdown]
# # Library Installation and Import

# %%
# !pip install -q -U ultralytics
# !pip install -q gdown
# !pip install -q pytest-shutil

# %%
import ultralytics
import gdown
import shutil

# %% [markdown]
# # Dataset Download and Preparation

# %%
gdown.download(id='1D4Tvi7EIEy1Ggiu52rN902pq2QnhP4hw', output='/kaggle/working/')
# Out:
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1D4Tvi7EIEy1Ggiu52rN902pq2QnhP4hw
# From (redirected): https://drive.google.com/uc?id=1D4Tvi7EIEy1Ggiu52rN902pq2QnhP4hw&confirm=t&uuid=51ed88cd-57c9-41c4-a3eb-e27915bc3885
# To: /kaggle/working/Wastebasket_trash_detecation.zip
# 100%|██████████| 441M/441M [00:06<00:00, 67.2MB/s]
# '/kaggle/working/Wastebasket_trash_detecation.zip'

# %%
# !unzip -q /kaggle/working/Wastebasket_trash_detecation.zip -d /kaggle/working/

# %%
# !rm -rf /kaggle/working/Wastebasket_trash_detecation.zip

# %%
shutil.copy('/kaggle/input/config/data.yaml', '/kaggle/working/config.yaml')
# Out:
# '/kaggle/working/config.yaml'

# %% [markdown]
# # Model

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.yaml')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
results = model.train(data='./config.yaml', epochs=300, patience=50)
# Out:
# Ultralytics YOLOv8.0.231 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# ...

# %%
# !zip -r runs.zip /kaggle/working/runs
# Out:
#   adding: kaggle/working/runs/ (stored 0%)
#   adding: kaggle/working/runs/detect/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/confusion_matrix_normalized.png (deflated 15%)
#   adding: kaggle/working/runs/detect/train/events.out.tfevents.1704031000.16b5915d5bc8.42.0 (deflated 85%)
#   adding: kaggle/working/runs/detect/train/val_batch0_labels.jpg (deflated 8%)
#   adding: kaggle/working/runs/detect/train/val_batch1_pred.jpg (deflated 7%)
#   adding: kaggle/working/runs/detect/train/val_batch2_labels.jpg (deflated 7%)
#   adding: kaggle/working/runs/detect/train/PR_curve.png (deflated 11%)
#   adding: kaggle/working/runs/detect/train/results.csv (deflated 86%)
#   adding: kaggle/working/runs/detect/train/train_batch1.jpg (deflated 4%)
#   adding: kaggle/working/runs/detect/train/results.png (deflated 8%)
#   adding: kaggle/working/runs/detect/train/P_curve.png (deflated 6%)
# ...

# %%
from IPython.display import FileLink
FileLink(r'runs.zip')
# Out:
# /kaggle/working/runs.zip

# %%
# !zip -r wandb.zip /kaggle/working/wandb
# Out:
#   adding: kaggle/working/wandb/ (stored 0%)
#   adding: kaggle/working/wandb/run-20231231_135748-3vjpbp09/ (stored 0%)
#   adding: kaggle/working/wandb/run-20231231_135748-3vjpbp09/run-3vjpbp09.wandb (deflated 87%)
#   adding: kaggle/working/wandb/run-20231231_135748-3vjpbp09/tmp/ (stored 0%)
#   adding: kaggle/working/wandb/run-20231231_135748-3vjpbp09/tmp/code/ (stored 0%)
#   adding: kaggle/working/wandb/run-20231231_135748-3vjpbp09/files/ (stored 0%)
#   adding: kaggle/working/wandb/run-20231231_135748-3vjpbp09/files/wandb-summary.json (deflated 71%)
#   adding: kaggle/working/wandb/run-20231231_135748-3vjpbp09/files/output.log (deflated 88%)
#   adding: kaggle/working/wandb/run-20231231_135748-3vjpbp09/files/conda-environment.yaml (deflated 67%)
#   adding: kaggle/working/wandb/run-20231231_135748-3vjpbp09/files/config.yaml (deflated 83%)
#   adding: kaggle/working/wandb/run-20231231_135748-3vjpbp09/files/media/ (stored 0%)
# ...

# %%
from IPython.display import FileLink
FileLink(r'wandb.zip')
# Out:
# /kaggle/working/wandb.zip
